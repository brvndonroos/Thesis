# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey_TE.xlsx")
print(df.head())
# Out:
#    age  gender                             education  \
# 0   22  Female  University of Applied Sciences (HBO)
# 1   23    Male  University of Applied Sciences (HBO)
# 2   26    Male  University of Applied Sciences (HBO)
# 3   28  Female                       University (WO)
# 4   26    Male  University of Applied Sciences (HBO)
#
#                                    employment_status financial_independence  \
# 0                          I'm currently not working                     No
# 1  I work occasionally (e.g. freelance, shifts, s...              Partially
# 2                                   I work full-time              Partially
# 3                                   I work part-time                    Yes
# 4                          I'm currently not working                     No
#
#    finlit_interest  finlit_inflation  finlit_risk  finlit_score  attitude_q1  \
# 0                1                 1            0             2            2
# 1                1                 1            0             2            5
# 2                1                 1            0             2            2
# 3                1                 1            0             2            4
# 4                1                 1            1             3            5
#
#    ...  pbc_q1  pbc_q2  pbc_q3_rev  pbc_q4  pbc_score  TPB_score  bnpl_used  \
# 0  ...       3       1           4       1       1.75   2.250000          1
# 1  ...       4       2           1       5       4.00   3.750000          1
# 2  ...       3       3           3       3       3.00   2.333333          0
# 3  ...       5       5           1       5       5.00   3.833333          1
# 4  ...       4       4           2       5       4.25   3.305556          1
#
#                     bnpl_frequency                 bnpl_repay  \
# 0     Frequently (monthly or more)  No, I've had difficulties
# 1  Occasionally (every few months)                Yes, always
# 2                              NaN                        NaN
# 3     Frequently (monthly or more)                Yes, always
# 4    Rarely (once or twice a year)                Yes, always
#
#                     bnpl_motivation
# 0        To try items before paying
# 1  I couldn't afford to pay upfront
# 2                               NaN
# 3        To try items before paying
# 4                  To delay payment
#
# [5 rows x 28 columns]

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.519533
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  240
# Model:                          Logit   Df Residuals:                      238
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.1340
# Time:                        23:57:34   Log-Likelihood:                -124.69
# converged:                       True   LL-Null:                       -143.98
# Covariance Type:            nonrobust   LLR p-value:                 5.269e-10
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.3444      0.320      7.332      0.000       1.718       2.971
# finlit_score    -0.9183      0.161     -5.695      0.000      -1.234      -0.602
# ================================================================================
# """

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.344823
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  240
# Model:                          Logit   Df Residuals:                      236
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.4252
# Time:                        23:57:34   Log-Likelihood:                -82.757
# converged:                       True   LL-Null:                       -143.98
# Covariance Type:            nonrobust   LLR p-value:                 2.305e-26
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -1.5792      1.551     -1.018      0.308      -4.619       1.460
# finlit_score                   -2.0657      0.900     -2.296      0.022      -3.829      -0.302
# attitude_score                  1.3623      0.587      2.323      0.020       0.213       2.512
# finlit_score:attitude_score     0.5531      0.346      1.597      0.110      -0.126       1.232
# ===============================================================================================
# """

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.446314
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  240
# Model:                          Logit   Df Residuals:                      236
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.2560
# Time:                        23:57:34   Log-Likelihood:                -107.12
# converged:                       True   LL-Null:                       -143.98
# Covariance Type:            nonrobust   LLR p-value:                 6.813e-16
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.6632      1.667     -0.398      0.691      -3.931       2.605
# finlit_score             -1.9215      0.904     -2.125      0.034      -3.693      -0.149
# sn_score                  0.9326      0.588      1.585      0.113      -0.220       2.086
# finlit_score:sn_score     0.4996      0.336      1.487      0.137      -0.159       1.158
# =========================================================================================
# """

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.496091
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  240
# Model:                          Logit   Df Residuals:                      236
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.1730
# Time:                        23:57:34   Log-Likelihood:                -119.06
# converged:                       True   LL-Null:                       -143.98
# Covariance Type:            nonrobust   LLR p-value:                 8.695e-11
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.1848      1.411     -0.131      0.896      -2.950       2.581
# finlit_score              -0.8596      0.704     -1.221      0.222      -2.239       0.520
# pbc_score                  0.8786      0.463      1.899      0.058      -0.028       1.785
# finlit_score:pbc_score    -0.0832      0.211     -0.395      0.693      -0.496       0.330
# ==========================================================================================
# """
