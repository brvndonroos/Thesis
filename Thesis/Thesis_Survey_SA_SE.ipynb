# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey_SE.xlsx")
print(df.head())
# Out:
#    age  gender                         education          employment_status  \
# 0   25  Female  Secondary school (VMBO/HAVO/VWO)  I'm currently not working
# 1   21    Male  Secondary school (VMBO/HAVO/VWO)           I work part-time
# 2   23    Male  Secondary school (VMBO/HAVO/VWO)           I work part-time
# 3   19    Male  Secondary school (VMBO/HAVO/VWO)  I'm currently not working
# 4   26  Female  Secondary school (VMBO/HAVO/VWO)           I work full-time
#
#   financial_independence  finlit_interest  finlit_inflation  finlit_risk  \
# 0                    Yes                1                 0            0
# 1                    Yes                1                 1            0
# 2              Partially                1                 1            0
# 3              Partially                1                 1            1
# 4              Partially                1                 1            0
#
#    finlit_score  attitude_q1  ...  pbc_q1  pbc_q2  pbc_q3_rev  pbc_q4  \
# 0             1            3  ...       5       5           1       4
# 1             2            3  ...       1       4           4       2
# 2             2            4  ...       5       4           1       4
# 3             3            1  ...       4       4           2       2
# 4             2            3  ...       4       5           1       5
#
#    pbc_score  TPB_score  bnpl_used                bnpl_frequency  \
# 0       4.75   3.166667          0                           NaN
# 1       2.25   2.527778          0                           NaN
# 2       4.50   3.833333          1  Frequently (monthly or more)
# 3       3.50   2.555556          0                           NaN
# 4       4.75   3.500000          0                           NaN
#
#           bnpl_repay             bnpl_motivation
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2  Most of the times  To try items before paying
# 3                NaN                         NaN
# 4                NaN                         NaN
#
# [5 rows x 28 columns]

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.427154
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                   71
# Model:                          Logit   Df Residuals:                       69
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.2815
# Time:                        23:57:32   Log-Likelihood:                -30.328
# converged:                       True   LL-Null:                       -42.213
# Covariance Type:            nonrobust   LLR p-value:                 1.086e-06
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        3.2756      0.742      4.414      0.000       1.821       4.730
# finlit_score    -1.5263      0.387     -3.945      0.000      -2.285      -0.768
# ================================================================================
# """

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.288708
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                   71
# Model:                          Logit   Df Residuals:                       67
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.5144
# Time:                        23:57:32   Log-Likelihood:                -20.498
# converged:                       True   LL-Null:                       -42.213
# Covariance Type:            nonrobust   LLR p-value:                 1.996e-09
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       5.7445      3.837      1.497      0.134      -1.776      13.265
# finlit_score                   -7.1023      2.833     -2.507      0.012     -12.654      -1.550
# attitude_score                 -0.9244      1.214     -0.762      0.446      -3.303       1.454
# finlit_score:attitude_score     2.1447      0.963      2.227      0.026       0.257       4.032
# ===============================================================================================
# """

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.404575
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                   71
# Model:                          Logit   Df Residuals:                       67
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.3195
# Time:                        23:57:32   Log-Likelihood:                -28.725
# converged:                       True   LL-Null:                       -42.213
# Covariance Type:            nonrobust   LLR p-value:                 5.958e-06
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.9292      4.204      0.221      0.825      -7.311       9.169
# finlit_score             -1.9525      2.184     -0.894      0.371      -6.233       2.328
# sn_score                  0.8652      1.567      0.552      0.581      -2.205       3.936
# finlit_score:sn_score     0.1778      0.803      0.221      0.825      -1.397       1.753
# =========================================================================================
# """

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.426720
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                   71
# Model:                          Logit   Df Residuals:                       67
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.2823
# Time:                        23:57:32   Log-Likelihood:                -30.297
# converged:                       True   LL-Null:                       -42.213
# Covariance Type:            nonrobust   LLR p-value:                 2.710e-05
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  4.1080      3.462      1.187      0.235      -2.678      10.894
# finlit_score              -1.9302      1.787     -1.080      0.280      -5.432       1.572
# pbc_score                 -0.2507      1.014     -0.247      0.805      -2.237       1.736
# finlit_score:pbc_score     0.1176      0.494      0.238      0.812      -0.850       1.085
# ==========================================================================================
# """
