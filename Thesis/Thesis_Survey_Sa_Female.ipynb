# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey_Female.xlsx")
print(df.head())
# Out:
#    age  gender                             education  \
# 0   22  Female  University of Applied Sciences (HBO)
# 1   25  Female      Secondary school (VMBO/HAVO/VWO)
# 2   28  Female                       University (WO)
# 3   23  Female  University of Applied Sciences (HBO)
# 4   20  Female  University of Applied Sciences (HBO)
#
#            employment_status financial_independence  finlit_interest  \
# 0  I'm currently not working                     No                1
# 1  I'm currently not working                    Yes                1
# 2           I work part-time                    Yes                1
# 3           I work part-time                     No                1
# 4           I work part-time              Partially                1
#
#    finlit_inflation  finlit_risk  finlit_score  attitude_q1  ...  pbc_q1  \
# 0                 1            0             2            2  ...       3
# 1                 0            0             1            3  ...       5
# 2                 1            0             2            4  ...       5
# 3                 1            0             2            1  ...       4
# 4                 1            0             2            1  ...       1
#
#    pbc_q2  pbc_q3_rev  pbc_q4  pbc_score  TPB_score  bnpl_used  \
# 0       1           4       1       1.75   2.250000          1
# 1       5           1       4       4.75   3.166667          0
# 2       5           1       5       5.00   3.833333          1
# 3       4           2       3       3.75   2.638889          1
# 4       1           3       2       1.75   1.972222          0
#
#                   bnpl_frequency                 bnpl_repay  \
# 0   Frequently (monthly or more)  No, I've had difficulties
# 1                            NaN                        NaN
# 2   Frequently (monthly or more)                Yes, always
# 3  Rarely (once or twice a year)                Yes, always
# 4                            NaN                        NaN
#
#               bnpl_motivation
# 0  To try items before paying
# 1                         NaN
# 2  To try items before paying
# 3  To try items before paying
# 4                         NaN
#
# [5 rows x 28 columns]

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.568256
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      176
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.1256
# Time:                        23:31:33   Log-Likelihood:                -101.15
# converged:                       True   LL-Null:                       -115.67
# Covariance Type:            nonrobust   LLR p-value:                 7.066e-08
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.9877      0.345      5.764      0.000       1.312       2.664
# finlit_score    -0.9516      0.193     -4.922      0.000      -1.330      -0.573
# ================================================================================
# """

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.392520
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      174
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.3960
# Time:                        23:31:33   Log-Likelihood:                -69.869
# converged:                       True   LL-Null:                       -115.67
# Covariance Type:            nonrobust   LLR p-value:                 9.887e-20
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.2032      1.464     -0.139      0.890      -3.073       2.667
# finlit_score                   -3.3111      1.095     -3.024      0.002      -5.458      -1.165
# attitude_score                  0.6839      0.525      1.304      0.192      -0.344       1.712
# finlit_score:attitude_score     1.0531      0.412      2.555      0.011       0.245       1.861
# ===============================================================================================
# """

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.525877
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      174
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.1908
# Time:                        23:31:33   Log-Likelihood:                -93.606
# converged:                       True   LL-Null:                       -115.67
# Covariance Type:            nonrobust   LLR p-value:                 1.414e-09
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0653      1.859      0.035      0.972      -3.578       3.708
# finlit_score             -1.8687      1.074     -1.741      0.082      -3.973       0.235
# sn_score                  0.6331      0.662      0.956      0.339      -0.665       1.931
# finlit_score:sn_score     0.4050      0.392      1.035      0.301      -0.362       1.172
# =========================================================================================
# """

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.545533
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      174
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.1605
# Time:                        23:31:33   Log-Likelihood:                -97.105
# converged:                       True   LL-Null:                       -115.67
# Covariance Type:            nonrobust   LLR p-value:                 4.306e-08
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.2903      1.526     -0.845      0.398      -4.281       1.701
# finlit_score              -0.1771      0.835     -0.212      0.832      -1.813       1.459
# pbc_score                  1.0822      0.497      2.178      0.029       0.108       2.056
# finlit_score:pbc_score    -0.2751      0.256     -1.074      0.283      -0.777       0.227
# ==========================================================================================
# """
