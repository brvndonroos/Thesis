# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey_Male.xlsx")
print(df.head())
# Out:
#    age gender                             education  \
# 0   23   Male  University of Applied Sciences (HBO)
# 1   26   Male  University of Applied Sciences (HBO)
# 2   21   Male      Secondary school (VMBO/HAVO/VWO)
# 3   26   Male  University of Applied Sciences (HBO)
# 4   23   Male      Secondary school (VMBO/HAVO/VWO)
#
#                                    employment_status financial_independence  \
# 0  I work occasionally (e.g. freelance, shifts, s...              Partially
# 1                                   I work full-time              Partially
# 2                                   I work part-time                    Yes
# 3                          I'm currently not working                     No
# 4                                   I work part-time              Partially
#
#    finlit_interest  finlit_inflation  finlit_risk  finlit_score  attitude_q1  \
# 0                1                 1            0             2            5
# 1                1                 1            0             2            2
# 2                1                 1            0             2            3
# 3                1                 1            1             3            5
# 4                1                 1            0             2            4
#
#    ...  pbc_q1  pbc_q2  pbc_q3_rev  pbc_q4  pbc_score  TPB_score  bnpl_used  \
# 0  ...       4       2           1       5       4.00   3.750000          1
# 1  ...       3       3           3       3       3.00   2.333333          0
# 2  ...       1       4           4       2       2.25   2.527778          0
# 3  ...       4       4           2       5       4.25   3.305556          1
# 4  ...       5       4           1       4       4.50   3.833333          1
#
#                     bnpl_frequency         bnpl_repay  \
# 0  Occasionally (every few months)        Yes, always
# 1                              NaN                NaN
# 2                              NaN                NaN
# 3    Rarely (once or twice a year)        Yes, always
# 4     Frequently (monthly or more)  Most of the times
#
#                     bnpl_motivation
# 0  I couldn't afford to pay upfront
# 1                               NaN
# 2                               NaN
# 3                  To delay payment
# 4        To try items before paying
#
# [5 rows x 28 columns]

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.309730
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  127
# Model:                          Logit   Df Residuals:                      125
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.3610
# Time:                        23:25:57   Log-Likelihood:                -39.336
# converged:                       True   LL-Null:                       -61.561
# Covariance Type:            nonrobust   LLR p-value:                 2.607e-11
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        5.0871      0.970      5.244      0.000       3.186       6.989
# finlit_score    -1.8188      0.380     -4.787      0.000      -2.563      -1.074
# ================================================================================
# """

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.177427
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  127
# Model:                          Logit   Df Residuals:                      123
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.6340
# Time:                        23:25:57   Log-Likelihood:                -22.533
# converged:                       True   LL-Null:                       -61.561
# Covariance Type:            nonrobust   LLR p-value:                 8.015e-17
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -4.9242      6.450     -0.763      0.445     -17.565       7.717
# finlit_score                   -0.7667      2.466     -0.311      0.756      -5.600       4.067
# attitude_score                  3.9158      2.838      1.380      0.168      -1.647       9.478
# finlit_score:attitude_score    -0.3992      1.056     -0.378      0.706      -2.470       1.671
# ===============================================================================================
# """

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.245370
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  127
# Model:                          Logit   Df Residuals:                      123
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.4938
# Time:                        23:25:57   Log-Likelihood:                -31.162
# converged:                       True   LL-Null:                       -61.561
# Covariance Type:            nonrobust   LLR p-value:                 3.968e-13
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -1.6775      4.889     -0.343      0.732     -11.260       7.905
# finlit_score             -1.5166      1.986     -0.763      0.445      -5.410       2.377
# sn_score                  2.2915      1.949      1.176      0.240      -1.528       6.111
# finlit_score:sn_score     0.0338      0.793      0.043      0.966      -1.520       1.587
# =========================================================================================
# """

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.300748
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  127
# Model:                          Logit   Df Residuals:                      123
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 04 Jun 2025   Pseudo R-squ.:                  0.3796
# Time:                        23:25:57   Log-Likelihood:                -38.195
# converged:                       True   LL-Null:                       -61.561
# Covariance Type:            nonrobust   LLR p-value:                 3.961e-10
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  6.3484      4.930      1.288      0.198      -3.314      16.011
# finlit_score              -3.1554      2.056     -1.535      0.125      -7.185       0.874
# pbc_score                 -0.2340      1.458     -0.160      0.873      -3.092       2.624
# finlit_score:pbc_score     0.3071      0.574      0.535      0.593      -0.819       1.433
# ==========================================================================================
# """
