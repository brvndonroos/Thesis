# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey_Employed.xlsx")
print(df.head())
# Out:
#    age  gender                             education  \
# 0   23    Male  University of Applied Sciences (HBO)
# 1   26    Male  University of Applied Sciences (HBO)
# 2   28  Female                       University (WO)
# 3   21    Male      Secondary school (VMBO/HAVO/VWO)
# 4   23    Male      Secondary school (VMBO/HAVO/VWO)
#
#                                    employment_status financial_independence  \
# 0  I work occasionally (e.g. freelance, shifts, s...              Partially
# 1                                   I work full-time              Partially
# 2                                   I work part-time                    Yes
# 3                                   I work part-time                    Yes
# 4                                   I work part-time              Partially
#
#    finlit_interest  finlit_inflation  finlit_risk  finlit_score  attitude_q1  \
# 0                1                 1            0             2            5
# 1                1                 1            0             2            2
# 2                1                 1            0             2            4
# 3                1                 1            0             2            3
# 4                1                 1            0             2            4
#
#    ...  pbc_q1  pbc_q2  pbc_q3_rev  pbc_q4  pbc_score  TPB_score  bnpl_used  \
# 0  ...       4       2           1       5       4.00   3.750000          1
# 1  ...       3       3           3       3       3.00   2.333333          0
# 2  ...       5       5           1       5       5.00   3.833333          1
# 3  ...       1       4           4       2       2.25   2.527778          0
# 4  ...       5       4           1       4       4.50   3.833333          1
#
#                     bnpl_frequency         bnpl_repay  \
# 0  Occasionally (every few months)        Yes, always
# 1                              NaN                NaN
# 2     Frequently (monthly or more)        Yes, always
# 3                              NaN                NaN
# 4     Frequently (monthly or more)  Most of the times
#
#                     bnpl_motivation
# 0  I couldn't afford to pay upfront
# 1                               NaN
# 2        To try items before paying
# 3                               NaN
# 4        To try items before paying
#
# [5 rows x 28 columns]

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.501864
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  217
# Model:                          Logit   Df Residuals:                      215
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 05 Jun 2025   Pseudo R-squ.:                  0.1725
# Time:                        00:29:43   Log-Likelihood:                -108.90
# converged:                       True   LL-Null:                       -131.61
# Covariance Type:            nonrobust   LLR p-value:                 1.594e-11
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.6441      0.371      7.122      0.000       1.916       3.372
# finlit_score    -1.0769      0.181     -5.955      0.000      -1.431      -0.722
# ================================================================================
# """

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.360735
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  217
# Model:                          Logit   Df Residuals:                      213
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 05 Jun 2025   Pseudo R-squ.:                  0.4052
# Time:                        00:29:43   Log-Likelihood:                -78.279
# converged:                       True   LL-Null:                       -131.61
# Covariance Type:            nonrobust   LLR p-value:                 5.726e-23
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.5729      1.523      0.376      0.707      -2.411       3.557
# finlit_score                   -2.8752      0.875     -3.284      0.001      -4.591      -1.159
# attitude_score                  0.5706      0.537      1.063      0.288      -0.482       1.623
# finlit_score:attitude_score     0.8354      0.324      2.575      0.010       0.199       1.471
# ===============================================================================================
# """

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.458625
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  217
# Model:                          Logit   Df Residuals:                      213
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 05 Jun 2025   Pseudo R-squ.:                  0.2438
# Time:                        00:29:43   Log-Likelihood:                -99.522
# converged:                       True   LL-Null:                       -131.61
# Covariance Type:            nonrobust   LLR p-value:                 7.508e-14
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.8422      1.896      0.444      0.657      -2.874       4.558
# finlit_score             -2.0350      0.932     -2.183      0.029      -3.862      -0.208
# sn_score                  0.5083      0.648      0.785      0.432      -0.761       1.777
# finlit_score:sn_score     0.4544      0.334      1.361      0.174      -0.200       1.109
# =========================================================================================
# """

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.469571
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              bnpl_used   No. Observations:                  217
# Model:                          Logit   Df Residuals:                      213
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 05 Jun 2025   Pseudo R-squ.:                  0.2258
# Time:                        00:29:43   Log-Likelihood:                -101.90
# converged:                       True   LL-Null:                       -131.61
# Covariance Type:            nonrobust   LLR p-value:                 7.778e-13
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.6314      1.636     -0.997      0.319      -4.838       1.575
# finlit_score              -0.2749      0.762     -0.361      0.718      -1.768       1.218
# pbc_score                  1.4444      0.543      2.658      0.008       0.379       2.509
# finlit_score:pbc_score    -0.3180      0.233     -1.363      0.173      -0.775       0.139
# ==========================================================================================
# """
