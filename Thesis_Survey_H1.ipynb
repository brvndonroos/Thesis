# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
df = pd.read_excel("BNPL_Survey.xlsx")
print(df.head())
# Out:
#    age  gender                             education  \
# 0   22  Female  University of Applied Sciences (HBO)
# 1   23    Male  University of Applied Sciences (HBO)
# 2   26    Male  University of Applied Sciences (HBO)
# 3   25  Female      Secondary school (VMBO/HAVO/VWO)
# 4   28  Female                       University (WO)
#
#                                    employment_status financial_independence  \
# 0                          I'm currently not working                     No
# 1  I work occasionally (e.g. freelance, shifts, s...              Partially
# 2                                   I work full-time              Partially
# 3                          I'm currently not working                    Yes
# 4                                   I work part-time                    Yes
#
#    finlit_interest  finlit_inflation  finlit_risk  finlit_score  attitude_q1  \
# 0                1                 1            0             2            2
# ...

# %%
model_h1 = smf.logit('bnpl_used ~ finlit_score', data=df).fit()

model_h1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.502418
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              bnpl_used   No. Observations:                  311
# Model:                          Logit   Df Residuals:                      309
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 13 May 2025   Pseudo R-squ.:                  0.1608
# Time:                        02:11:10   Log-Likelihood:                -156.25
# converged:                       True   LL-Null:                       -186.19
# Covariance Type:            nonrobust   LLR p-value:                 1.008e-14
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model_h2 = smf.logit('bnpl_used ~ finlit_score * attitude_score', data=df).fit()
model_h2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.339702
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              bnpl_used   No. Observations:                  311
# Model:                          Logit   Df Residuals:                      307
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 14 May 2025   Pseudo R-squ.:                  0.4326
# Time:                        01:18:50   Log-Likelihood:                -105.65
# converged:                       True   LL-Null:                       -186.19
# Covariance Type:            nonrobust   LLR p-value:                 1.066e-34
# ...
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
model_h3 = smf.logit('bnpl_used ~ finlit_score * sn_score', data=df).fit()
model_h3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.445310
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              bnpl_used   No. Observations:                  311
# Model:                          Logit   Df Residuals:                      307
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 13 May 2025   Pseudo R-squ.:                  0.2562
# Time:                        17:27:11   Log-Likelihood:                -138.49
# converged:                       True   LL-Null:                       -186.19
# Covariance Type:            nonrobust   LLR p-value:                 1.513e-20
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.488972
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              bnpl_used   No. Observations:                  311
# Model:                          Logit   Df Residuals:                      307
# Method:                           MLE   Df Model:                            3
# Date:                Tue, 13 May 2025   Pseudo R-squ.:                  0.1833
# Time:                        17:28:25   Log-Likelihood:                -152.07
# converged:                       True   LL-Null:                       -186.19
# Covariance Type:            nonrobust   LLR p-value:                 1.014e-14
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
model_h4 = smf.logit('bnpl_used ~ finlit_score * pbc_score', data=df).fit()
model_h4.summary()
